# %%
def copy_samples_tpch():
    for table in ("customer", "lineitem", "nation", "orders", "part", "partsupp", "region", "supplier"):
        spark.sql(f"""
            CREATE OR REPLACE TABLE prd.demo_tables.{table} AS
            SELECT * FROM samples.tpch.{table}""")

# copy_samples_tpch()

# %%
# %sql
USE CATALOG prd;
SELECT COUNT(*) FROM demo_tables.nation;
