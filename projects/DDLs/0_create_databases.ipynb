# %%
# %sql
USE CATALOG prd;

CREATE SCHEMA IF NOT EXISTS demo_volumes;
CREATE SCHEMA IF NOT EXISTS demo_functions;
CREATE SCHEMA IF NOT EXISTS demo_views;
CREATE SCHEMA IF NOT EXISTS demo_tables;
CREATE SCHEMA IF NOT EXISTS l_bronze;
CREATE SCHEMA IF NOT EXISTS l_silver;
CREATE SCHEMA IF NOT EXISTS l_gold;
